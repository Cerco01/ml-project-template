# %% [markdown]
# # [Título del Proyecto]
#
# ## Resumen
#
# [Breve descripción de qué hace este proyecto, el dataset, y la conclusión principal.]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("./apple.mplstyle")
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


SEPARATOR = 120 * "-"  # Línea para separar en consola distintos 'prints'.

# %% [markdown]
# ## 1. Exploración del dataset (EDA)

# %% [markdown]
# ### 1.1. Análisis univariante

# %% [markdown]
# #### Variables categóricas

# %%
# Código para cargar y explorar variables categóricas

# %% [markdown]
# #### Variables numéricas

# %%
# Código para explorar variables numéricas

# %% [markdown]
# ### 1.2. Análisis multivariante

# %% [markdown]
# #### Correlaciones (heatmap)

# %%
# Código para heatmap de correlaciones

# %% [markdown]
# ### 1.3. Outliers

# %%
# Código para detección de outliers

# %% [markdown]
# ### 1.4. Valores faltantes

# %%
# Código para verificar valores nulos

# %% [markdown]
# ## 2. Preprocesamiento

# %% [markdown]
# ### 2.1. Feature engineering

# %%
# Código de feature engineering

# %% [markdown]
# ### 2.2. Split en train y test

# %% [markdown]
# #### Nota sobre data leakage
#
# Prefiero hacer el `split` antes del encoding porque sino los tests nos pueden mostrar que el modelo futuro es mejor de lo que realmente es al haber sido entrenado con las "respuestas".

# %%
# Código para dividir en train y test

# %% [markdown]
# ### 2.3. Encoding de variables

# %%
# Código para OneHotEncoder o LabelEncoder

# %% [markdown]
# ### 2.4. Limpieza de columnas

# %%
# Código para eliminar columnas originales de texto

# %% [markdown]
# ### 2.5. Escalado de variables numéricas

# %%
# Código para StandardScaler o MinMaxScaler

# %% [markdown]
# ### 2.6. Concatenación de datasets procesados

# %%
# Código para concatenar variables escaladas y encodeadas

# %% [markdown]
# ### 2.7. Guardado de datasets

# %%
# Código para guardar datasets procesados en data/processed/

# %% [markdown]
# ## 3. Modelado

# %% [markdown]
# ### 3.1. Modelo base

# %% [markdown]
# #### Entrenamiento

# %%
# Código para instanciar y entrenar el modelo base

# %% [markdown]
# #### Evaluación

# %%
# Código para predecir y calcular métricas

# %% [markdown]
# #### Interpretación de métricas

# %% [markdown]
# [Explicación de las métricas obtenidas y qué significan para el problema.]

# %% [markdown]
# ### 3.2. Optimización del modelo

# %% [markdown]
# #### GridSearchCV

# %%
# Código para GridSearchCV con validación cruzada

# %% [markdown]
# #### Evaluación del modelo optimizado

# %%
# Código para evaluar el mejor modelo en test

# %% [markdown]
# ### 3.3. Comparación de modelos

# %% [markdown]
# #### Tabla comparativa

# %%
# Código para crear DataFrame comparativo

# %% [markdown]
# #### Visualización comparativa

# %%
# Código para gráfico de barras o comparación visual

# %% [markdown]
# ## 4. Conclusiones

# %% [markdown]
# [Puntos clave del análisis, modelo recomendado, y próximos pasos.]
